# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
test_loss = joblib.load("/data03/christopher/m6anet_new_dataprep_results/prod_pooling_attention_1_neighbor_regularized_read_info_lite_balanced_test_loss/test_results.joblib")

# %%
test_loss.keys()
# Out:
# dict_keys(['compute_time', 'accuracy', 'roc_auc', 'pr_auc', 'avg_loss', 'accuracy_read', 'roc_auc_read', 'pr_auc_read', 'avg_loss_read'])

# %%
plt.plot(test_loss['pr_auc_read'], label='pr_auc_read')
plt.plot(test_loss['pr_auc'], label='pr_auc')
plt.title('pr_auc')
plt.legend()

# %%
plt.plot(test_loss['avg_loss'], label='avg_loss_site')
plt.plot(test_loss['avg_loss_read'], label='avg_loss_read')
plt.title('weighted_loss')
plt.legend()
